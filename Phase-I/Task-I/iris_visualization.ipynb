# %% [markdown]
# # Task 1: Exploring and Visualizing a Simple Dataset

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load the Dataset using Pandas

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ### Summary Statistics with .info() and .describe()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Visualize the provided Data

# %% [markdown]
# #### Scatter Plot

# %%
plt.scatter(df['sepal.length'], df['sepal.width'], c='red')
plt.xlabel('Length')
plt.ylabel('Width')
plt.title('Iris Dataset: Sepal Length vs Sepal Width')
plt.show()

# %%
plt.scatter(df['petal.length'], df['petal.width'], c='blue')
plt.xlabel('Length')
plt.ylabel('Width')
plt.title('Iris Dataset: Petal Length vs Petal Width')
plt.show()

# %%
sns.scatterplot(data = df, x='sepal.length', y='sepal.width', hue='variety')
# Out:
# <Axes: xlabel='sepal.length', ylabel='sepal.width'>

# %%
sns.scatterplot(data=df, x='petal.length', y='petal.width', hue='variety')
# Out:
# <Axes: xlabel='petal.length', ylabel='petal.width'>

# %% [markdown]
# #### Histograms

# %%
plt.hist(df['sepal.length'], bins=20,color='red', edgecolor='black')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Length')
# Out:
# Text(0.5, 1.0, 'Distribution of Sepal Length')

# %%
plt.hist(df['sepal.width'], bins=20, color='red', edgecolor='black')
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Width')
# Out:
# Text(0.5, 1.0, 'Distribution of Sepal Width')

# %%
plt.hist(df['petal.length'], bins=20, color='blue', edgecolor='black')
plt.xlabel('Petal Length')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
features = df.columns[:-1]

for col in features:
    plt.figure(figsize=(6,4))
    plt.hist(df[col], bins=20, color=(col=='sepal.length' or col=='sepal.width') and 'red' or 'blue', edgecolor='black')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
features = df.columns[:-1]

for col in features:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], bins=20, color=(col=='sepal.length' or col=='sepal.width') and 'red' or 'blue')
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
numeric_cols = ['sepal.length', 'sepal.width', 'petal.length', 'petal.width']

plt.figure(figsize=(8, 5))
plt.boxplot([df[col] for col in numeric_cols], labels=numeric_cols)
plt.title('Boxplot of Iris Dataset Features')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1092\3002766981.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df[col] for col in numeric_cols], labels=numeric_cols)

# %%
df_melted = df.melt(
    id_vars='variety',
    value_vars=numeric_cols,
    var_name='Feature',
    value_name='Value'
)

plt.figure(figsize=(12,6))

sns.boxplot(
    data=df_melted,
    x='Feature',
    y='Value',
    hue='variety'
)

plt.title('Feature Distribution by Species')
plt.xticks(rotation=45)

plt.show()

# %%
sns.pairplot(
    df,
    hue='variety'
)

plt.show()
